# %%
import pyvene

# %%
import os

import torch
import pandas as pd
import numpy as np
from pyvene import embed_to_distrib, top_vals, format_token
from pyvene import (
    IntervenableModel,
    VanillaIntervention, Intervention,
    RepresentationConfig,
    IntervenableConfig,
    ConstantSourceIntervention,
    LocalistRepresentationIntervention
)
from pyvene import create_gpt2

# %config InlineBackend.figure_formats = ['svg']
from plotnine import (
    ggplot,
    geom_tile,
    aes,
    facet_wrap,
    theme,
    element_text,
    geom_bar,
    geom_hline,
    scale_y_log10,
    xlab, ylab, ylim,
    scale_y_discrete, scale_y_continuous, ggsave
)
from plotnine.scales import scale_y_reverse, scale_fill_cmap
from tqdm import tqdm

titles={
    "block_output": "single restored layer in GPT2-XL",
    "mlp_activation": "center of interval of 10 patched mlp layer",
    "attention_output": "center of interval of 10 patched attn layer"
}

colors={
    "block_output": "Purples",
    "mlp_activation": "Greens",
    "attention_output": "Reds"
}

# %%
import patchworklib as pw

# %% [markdown]
# ### Pomocnicze funkcje

# %%
class NoiseIntervention(ConstantSourceIntervention, LocalistRepresentationIntervention):
    def __init__(self, embed_dim, subject_len=4, **kwargs):
        super().__init__()
        self.interchange_dim = embed_dim
        rs = np.random.RandomState(1)
        prng = lambda *shape: rs.randn(*shape)
        self.noise = torch.from_numpy(
            prng(1, subject_len, embed_dim)).to(device)
        self.noise_level = 0.13462981581687927

    def forward(self, base, source=None, subspaces=None):
        base[..., : self.interchange_dim] += self.noise * self.noise_level
        return base

    def __str__(self):
        return f"NoiseIntervention(embed_dim={self.embed_dim})"

# %%
def generate_noise_intervention_subclass(subject_len):
    class CustomNoiseIntervention(NoiseIntervention):
        def __init__(self, embed_dim, **kwargs):
            super().__init__(embed_dim, subject_len=subject_len, **kwargs)

        def __str__(self):
            return f"CustomNoiseIntervention(embed_dim={self.interchange_dim}, subject_len={subject_len})"

    return CustomNoiseIntervention

# %%
def restore_corrupted_with_interval_config(
    layer, stream="mlp_activation", window=10, num_layers=48, index=[0,1], embed_dim=1600, subject_len=4):
    start = max(0, layer - window // 2)
    end = min(num_layers, layer - (-window // 2))
    config = IntervenableConfig(
        representations=[
            RepresentationConfig(
                0,       # layer
                "block_input",  # intervention type
            ),
        ] + [
            RepresentationConfig(
                i,       # layer
                stream,  # intervention type
        ) for i in range(start, end)],
        intervention_types=\
            [generate_noise_intervention_subclass(subject_len)]+[VanillaIntervention]*(end-start),
    )
    return config

def analyze_sentence(model, tokenizer, config, sentence, target_token, index, save_path="./results_gpt", streams=["block_output", "mlp_activation", "attention_output"]):
    # Tokenize input
    base_input = tokenizer(sentence, return_tensors="pt").to(device)
    target_token_id = tokenizer.encode(target_token)[0]

    for stream in streams:
        data = []
        for layer_i in tqdm(range(model.config.n_layer), desc=f"Analyzing {stream}"):
            for pos_i in range(len(tokenizer.tokenize(sentence))):
                config = restore_corrupted_with_interval_config(layer=layer_i, stream=stream, num_layers=model.config.n_layer, subject_len=len(index))
                intervenable = IntervenableModel(config, model)
                _, counterfactual_outputs = intervenable(
                    base_input,
                    [None] + [base_input] * (len(config.representations) - 1),
                    {
                        "sources->base": (
                            [None] + [[[pos_i]]] * (len(config.representations) - 1),
                            [[index]] + [[[pos_i]]] * (len(config.representations) - 1),
                        )
                    },
                )
                distrib = embed_to_distrib(model, counterfactual_outputs.last_hidden_state, logits=False)
                prob = distrib[0][-1][target_token_id].detach().cpu().item()
                data.append({"layer": layer_i, "pos": pos_i, "prob": prob})

        df = pd.DataFrame(data)
        os.makedirs(save_path, exist_ok=True)
        df.to_csv(f"{save_path}/{stream}_{target_token.replace(' ', '')}.csv")

# %%
import pandas as pd
from plotnine import *

def plot_results_comparison(filename, target, sentence, streams=["block_output", "mlp_activation", "attention_output"]):
    for stream in streams:
        # Generate file paths for both models
        file1 = f"./{filename}/results_gptxl/{stream}_{target[1:]}.csv"
        file2 = f"./{filename}/results_boolq/{stream}_{target[1:]}.csv"
        
        # Load data from both files
        df1 = pd.read_csv(file1)
        df2 = pd.read_csv(file2)

        # Add a column to identify the model
        df1["model"] = "GPT2-XL"
        df2["model"] = "Boolq-GPT2-XL"

        # Concatenate the two DataFrames
        df = pd.concat([df1, df2], ignore_index=True)

        # Ensure correct data types
        df["layer"] = df["layer"].astype(int)
        df["pos"] = df["pos"].astype(int)
        df["p(token)"] = df["prob"].astype(float)

        # Prepare custom labels for y-axis
        custom_labels = tokenizer.tokenize(sentence)
        custom_labels = [label.lstrip("Ġ_") for label in custom_labels]
        breaks = list(range(len(custom_labels)))

        # Create the plot
        df_gptxl = df[df["model"] == "GPT2-XL"]
        df_gptboolq = df[df["model"] == "Boolq-GPT2-XL"]

        max_prob = max(df_gptxl["p(token)"].max(), df_gptboolq["p(token)"].max())
        # Create plot for GPT-XL
        plot_gptxl = (
            ggplot(df_gptxl, aes(x="layer", y="pos"))
            + geom_tile(aes(fill="p(token)"))
            + scale_fill_gradient(low="white", high="blue", name="p(token)", limits=(0, max_prob))
            + xlab(f"{stream}")
            + scale_x_continuous(limits=(0, 48), breaks=list(range(0, 49, 8)))
            + scale_y_reverse(
                limits=(-0.5, len(custom_labels) - 0.5),
                breaks=breaks, labels=custom_labels
            )
            + theme(figure_size=(10, 5))  # Adjust figure size
            + theme(
                legend_position="right",  # Place legend on the right
                legend_box_margin=0.2,   # Add margin around legend
                legend_key_width=10,     # Increase width of the legend key
                legend_key_height=500,    # Increase height of the legend key
                legend_title=element_text(size=14),  # Adjust legend title size
                legend_text=element_text(size=12)   # Adjust legend text size
            )
            + ylab("")
            + theme(axis_text_y=element_text(angle=50, hjust=1))
            + ggtitle("GPT2-XL")
        )

        # Create plot for GPT2-XL-Boolq
        plot_gptboolq = (
            ggplot(df_gptboolq, aes(x="layer", y="pos"))
            + geom_tile(aes(fill="p(token)"))
            + scale_fill_gradient(low="white", high="red", name="p(token)", limits=(0, max_prob))
            + xlab(f"{stream}")
            + scale_x_continuous(limits=(0, 24), breaks=list(range(0, 25, 4)))
            + scale_y_reverse(
                limits=(-0.5, len(custom_labels) - 0.5),
                breaks=breaks, labels=custom_labels
            )
            + theme(figure_size=(10, 5))  # Adjust figure size
            + theme(
                legend_position="right",  # Place legend on the right
                legend_box_margin=0.2,   # Add margin around legend
                legend_key_width=10,     # Increase width of the legend key
                legend_key_height=500,    # Increase height of the legend key
                legend_title=element_text(size=14),  # Adjust legend title size
                legend_text=element_text(size=12)   # Adjust legend text size
            )
            + ylab("")
            + theme(axis_text_y=element_text(angle=50, hjust=1))
            + ggtitle("GPT2-XL-Boolq")
        )

        plot_gptxl = pw.load_ggplot(plot_gptxl)
        plot_gptboolq = pw.load_ggplot(plot_gptboolq)

        # Display the plots
        display(plot_gptxl | plot_gptboolq)

# %% [markdown]
# ## Wczytanie zbioru

# %%
from datasets import load_dataset

ds = load_dataset("google/boolq")

# %%
for i in range(40, 100):
    print(f"Question: {ds['train'][i]['question']}")
    print(f"Answer: {ds['train'][i]['answer']}")
    print()
# Out:
# Question: is the blues brothers based on a true story
# Answer: False
#
# Question: is newcastle upon tyne the same as newcastle
# Answer: True
#
# Question: is post office and royal mail the same
# Answer: False
#
# Question: has any supreme court nominee not been confirmed
# Answer: True
#
# Question: is thanksgiving always the last thursday of the month
# Answer: True
#
# Question: is lord of the rings after the hobbit
# Answer: True
#
# Question: is the fallen movie going to have a sequel
# Answer: False
#
# Question: does anyone on instagram have 1 billion followers
# Answer: False
#
# Question: in the phantom menace is padme the queen
# Answer: True
#
# Question: is lord of the rings considered an epic
# Answer: True
#
# Question: does the euro sign go before the number
# Answer: True
#
# Question: can stainless steel be used on induction cooktop
# Answer: True
#
# Question: is job termination the same as being fired
# Answer: True
#
# ...

# %% [markdown]
# ### Załadowanie modeli

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"

config, tokenizer, gpt_2xl = create_gpt2(name="gpt2-xl", cache_dir="/net/pr2/projects/plgrid/plggaigraphicsk46/.cache")
gpt_2xl.to(device)

# %%
config_boolq, tokenizer_boolq, gpt_boolq = create_gpt2(name="utahnlp/boolq_gpt2-xl_seed-1", cache_dir="/net/pr2/projects/plgrid/plggaigraphicsk46/.cache")
gpt_boolq.to(device)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# loaded model
# GPT2Model(
#   (wte): Embedding(50257, 1600)
#   (wpe): Embedding(1024, 1600)
#   (drop): Dropout(p=0.1, inplace=False)
#   (h): ModuleList(
#     (0-47): 48 x GPT2Block(
#       (ln_1): LayerNorm((1600,), eps=1e-05, elementwise_affine=True)
#       (attn): GPT2Attention(
#         (c_attn): Conv1D(nf=4800, nx=1600)
#         (c_proj): Conv1D(nf=1600, nx=1600)
#         (attn_dropout): Dropout(p=0.1, inplace=False)
#         (resid_dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ln_2): LayerNorm((1600,), eps=1e-05, elementwise_affine=True)
#       (mlp): GPT2MLP(
#         (c_fc): Conv1D(nf=6400, nx=1600)
#         (c_proj): Conv1D(nf=1600, nx=6400)
#         (act): NewGELUActivation()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (ln_f): LayerNorm((1600,), eps=1e-05, elementwise_affine=True)
# )

# %% [markdown]
# ### Sprawdzenie prawdopodobieństwa odpowiedzi

# %%
question = "Question: Is thanksgiving always the last thursday of the month? Answer:"

input_gpt2 = tokenizer(question, return_tensors="pt").to(device)
input_boolq = tokenizer_boolq(question, return_tensors="pt").to(device)

result_gpt2 = gpt_2xl(**input_gpt2)
result_boolq = gpt_boolq(**input_boolq)

distrib_gpt2 = embed_to_distrib(gpt_2xl, result_gpt2.last_hidden_state, logits=False)
distrib_boolq = embed_to_distrib(gpt_boolq, result_boolq.last_hidden_state, logits=False)

print(top_vals(tokenizer, distrib_gpt2[0][-1], 5))
print(top_vals(tokenizer_boolq, distrib_boolq[0][-1], 5))
# Out:
# _No                  0.2666878402233124
# _Yes                 0.13023433089256287
# _Thanks              0.07958301156759262
# _It                  0.07000087201595306
# _The                 0.052448779344558716
# None
# _No                  0.5584375262260437
# _no                  0.09378563612699509
# _Not                 0.04577360302209854
# _Yes                 0.040115196257829666
# \n                   0.025408299639821053
# None

# %% [markdown]
# ### example 1.

# %%
question = "Question: Does marvel own the rights to fantastic four? Answer:"

input_gpt2 = tokenizer(question, return_tensors="pt").to(device)
input_boolq = tokenizer_boolq(question, return_tensors="pt").to(device)

result_gpt2 = gpt_2xl(**input_gpt2)
result_boolq = gpt_boolq(**input_boolq)

distrib_gpt2 = embed_to_distrib(gpt_2xl, result_gpt2.last_hidden_state, logits=False)
distrib_boolq = embed_to_distrib(gpt_boolq, result_boolq.last_hidden_state, logits=False)

print(top_vals(tokenizer, distrib_gpt2[0][-1], 5))
print(top_vals(tokenizer_boolq, distrib_boolq[0][-1], 5))

# %%
question = "Question: Does marvel own the rights to fantastic four? Answer:"

print(tokenizer.tokenize(question))
print(tokenizer_boolq.tokenize(question))
# Out:
# ['Question', ':', 'ĠDoes', 'Ġmarvel', 'Ġown', 'Ġthe', 'Ġrights', 'Ġto', 'Ġfantastic', 'Ġfour', '?', 'ĠAnswer', ':']
# ['Question', ':', 'ĠDoes', 'Ġmarvel', 'Ġown', 'Ġthe', 'Ġrights', 'Ġto', 'Ġfantastic', 'Ġfour', '?', 'ĠAnswer', ':']

# %%
print(tokenizer.tokenize(question)[3])
# Out:
# Ġmarvel

# %%
question = "Question: Does marvel own the rights to fantastic four? Answer:"
target = " Yes"
subject = [3]
dname="marvel"
print(question, ":")
print("GPT2-xl: ")
analyze_sentence(gpt_2xl, tokenizer, config, question, target, subject, f"./{dname}/results_gptxl")
print("GPT2-xl-boolq: ")
analyze_sentence(gpt_boolq, tokenizer_boolq, config_boolq, question, target, subject, f"./{dname}/results_boolq")
print("")
# Out:
# Question: Does marvel own the rights to fantastic four? Answer: :
# GPT2-xl:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [02:57<00:00,  3.70s/it]
# GPT2-xl-boolq:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [02:57<00:00,  3.70s/it]

# %%
plot_results_comparison(
    filename="marvel",
    target=" Yes",
    sentence="Question: Does marvel own the rights to fantastic four? Answer:"
)

# %% [markdown]
# ### example 2.

# %%
question = "Question: Is porto rico a part of the united states? Answer:"

print(tokenizer.tokenize(question))
print(tokenizer_boolq.tokenize(question))
# Out:
# ['Question', ':', 'ĠIs', 'Ġport', 'o', 'Ġr', 'ico', 'Ġa', 'Ġpart', 'Ġof', 'Ġthe', 'Ġunited', 'Ġstates', '?', 'ĠAnswer', ':']
# ['Question', ':', 'ĠIs', 'Ġport', 'o', 'Ġr', 'ico', 'Ġa', 'Ġpart', 'Ġof', 'Ġthe', 'Ġunited', 'Ġstates', '?', 'ĠAnswer', ':']

# %%
question = "Question: Is porto rico a part of the united states? Answer:"
target = " Yes"
subject = [10, 11, 12]
dname="portorico"
print(sentence, ":")
print("GPT2-xl: ")
analyze_sentence(gpt_2xl, tokenizer, config, question, target, subject, f"./{dname}/results_gptxl")
print("GPT2-xl-boolq: ")
analyze_sentence(gpt_boolq, tokenizer_boolq, config_boolq, question, target, subject, f"./{dname}/results_boolq")
print("")
# Out:
# Question: Is porto rico a part of the united states? Answer: :
# GPT2-xl:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [03:38<00:00,  4.54s/it]
# GPT2-xl-boolq:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [03:38<00:00,  4.55s/it]

# %%
plot_results_comparison(
    filename="portorico",
    target=target,
    sentence="Question: Is porto rico a part of the united states? Answer:"
)

# %% [markdown]
# ### example 2. - NO

# %%
question = "Question: Is porto rico a part of japan? Answer:"

print(tokenizer.tokenize(question))
print(tokenizer_boolq.tokenize(question))
# Out:
# ['Question', ':', 'ĠIs', 'Ġport', 'o', 'Ġr', 'ico', 'Ġa', 'Ġpart', 'Ġof', 'Ġj', 'apan', '?', 'ĠAnswer', ':']
# ['Question', ':', 'ĠIs', 'Ġport', 'o', 'Ġr', 'ico', 'Ġa', 'Ġpart', 'Ġof', 'Ġj', 'apan', '?', 'ĠAnswer', ':']

# %%
question = "Question: Is porto rico a part of japan? Answer:"
target = "No"
subject = [10, 11]
dname="portorico"
print("GPT2-xl: ")
analyze_sentence(gpt_2xl, tokenizer, config, question, target, subject, f"./{dname}/results_gptxl")
print("GPT2-xl-boolq: ")
analyze_sentence(gpt_boolq, tokenizer_boolq, config_boolq, question, target, subject, f"./{dname}/results_boolq")
print("")
# Out:
# GPT2-xl:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [03:22<00:00,  4.21s/it]
# GPT2-xl-boolq:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [03:23<00:00,  4.23s/it]

# %%
plot_results_comparison(
    filename="portorico",
    target=" No",
    sentence="Question: Is porto rico a part of japan? Answer:"
)

# %% [markdown]
# ### example 3.

# %%
question = "Question: Is london the capital of the united kingdom? Answer:"

print(tokenizer.tokenize(question))
print(tokenizer_boolq.tokenize(question))
# Out:
# ['Question', ':', 'ĠIs', 'Ġl', 'ondon', 'Ġthe', 'Ġcapital', 'Ġof', 'Ġthe', 'Ġunited', 'Ġkingdom', '?', 'ĠAnswer', ':']
# ['Question', ':', 'ĠIs', 'Ġl', 'ondon', 'Ġthe', 'Ġcapital', 'Ġof', 'Ġthe', 'Ġunited', 'Ġkingdom', '?', 'ĠAnswer', ':']

# %%
print(tokenizer.tokenize(question)[3:5])
# Out:
# ['Ġl', 'ondon']

# %%
question = "Question: Is london the capital of the united kingdom? Answer:"
target = " Yes"
subject = [3,4]
dname="london"
print(question, ":")
print("GPT2-xl: ")
analyze_sentence(gpt_2xl, tokenizer, config, question, target, subject, f"./{dname}/results_gptxl")
print("GPT2-xl-boolq: ")
analyze_sentence(gpt_boolq, tokenizer_boolq, config_boolq, question, target, subject, f"./{dname}/results_boolq")
print("")
# Out:
# Question: Is london the capital of the united kingdom? Answer: :
# GPT2-xl:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [03:11<00:00,  3.99s/it]
# GPT2-xl-boolq:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [03:08<00:00,  3.94s/it]

# %%
plot_results_comparison(
    filename=dname,
    target=target,
    sentence="Question: Is london the capital of the united kingdom? Answer:"
)

# %% [markdown]
# ### example 4.

# %%
question = "Question: Is lord of the rings after the hobbit? Answer:"

print(tokenizer.tokenize(question))
print(tokenizer_boolq.tokenize(question))
# Out:
# ['Question', ':', 'ĠIs', 'Ġlord', 'Ġof', 'Ġthe', 'Ġrings', 'Ġafter', 'Ġthe', 'Ġhob', 'bit', '?', 'ĠAnswer', ':']
# ['Question', ':', 'ĠIs', 'Ġlord', 'Ġof', 'Ġthe', 'Ġrings', 'Ġafter', 'Ġthe', 'Ġhob', 'bit', '?', 'ĠAnswer', ':']

# %%
print(tokenizer.tokenize(question)[6])
# Out:
# Ġrings

# %%
question = "Question: Is lord of the rings after the hobbit? Answer:"
target = " Yes"
subject = [3, 4, 5, 6]
dname="lotr"
print(question, ":")
print("GPT2-xl: ")
analyze_sentence(gpt_2xl, tokenizer, config, question, target, subject, f"./{dname}/results_gptxl")
print("GPT2-xl-boolq: ")
analyze_sentence(gpt_boolq, tokenizer_boolq, config_boolq, question, target, subject, f"./{dname}/results_boolq")
print("")
# Out:
# Question: Is lord of the rings after the hobbit? Answer: :
# GPT2-xl:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [03:11<00:00,  3.99s/it]
# GPT2-xl-boolq:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [03:11<00:00,  3.98s/it]

# %%
question = "Question: Is lord of the rings after the hobbit? Answer:"
target = " Yes"
dname="lotr"

plot_results_comparison(
    filename=dname,
    target=target,
    sentence=question
)

# %% [markdown]
# ### example 5.

# %%
question = "Question: Is rogue one part of the star wars? Answer:"

print(tokenizer.tokenize(question))
print(tokenizer_boolq.tokenize(question))
print(tokenizer.tokenize(question)[9])
# Out:
# ['Question', ':', 'ĠIs', 'Ġrogue', 'Ġone', 'Ġpart', 'Ġof', 'Ġthe', 'Ġstar', 'Ġwars', '?', 'ĠAnswer', ':']
# ['Question', ':', 'ĠIs', 'Ġrogue', 'Ġone', 'Ġpart', 'Ġof', 'Ġthe', 'Ġstar', 'Ġwars', '?', 'ĠAnswer', ':']
# Ġwars

# %%
question = "Question: Is rogue one part of the star wars? Answer:"
target = " Yes"
subject = [7, 8, 9]
dname="starwars"
print(question, ":")
print("GPT2-xl: ")
analyze_sentence(gpt_2xl, tokenizer, config, question, target, subject, f"./{dname}/results_gptxl")
print("GPT2-xl-boolq: ")
analyze_sentence(gpt_boolq, tokenizer_boolq, config_boolq, question, target, subject, f"./{dname}/results_boolq")
print("")
# Out:
# Question: Is rogue one part of the star wars? Answer: :
# GPT2-xl:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [02:58<00:00,  3.72s/it]
# GPT2-xl-boolq:
# ...
# Analyzing attention_output: 100%|██████████| 48/48 [02:58<00:00,  3.71s/it]

# %%
plot_results_comparison(
    filename=dname,
    target=target,
    sentence="Question: Is rogue one part of the star wars? Answer:"
)
